# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('../data/interim/radius3.csv',index_col=[0]).reset_index(drop=True)

df.head()
# Out:
#       Country Name  Year  \
# 0          Ukraine  2002
# 1          Ukraine  2003
# 2  Kyrgyz Republic  2007
# 3           Panama  2007
# 4  Kyrgyz Republic  2008
#
#    Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)  \
# 0                                          88.543221
# 1                                          88.543221
# 2                                          95.692841
# 3                                          61.490292
# 4                                          95.692841
#
#    Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)  \
# 0                                            0.00000
# 1                                            0.00000
# 2                                            0.03193
# 3                                            0.25529
# 4                                            0.03193
#
#    Poverty headcount ratio at $3.65 a day (2017 PPP) (% of population)  \
# ...

# %%
np.percentile(df['Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)'],2)
# Out:
# 30.17124731063844

# %%
np.percentile(df['Poverty headcount ratio at $3.65 a day (2017 PPP) (% of population)'],98)
# Out:
# 51.634

# %%
np.percentile(df['Inflation, consumer prices (annual %)'],98)#20
# Out:
# 10.99603935207675

# %%
np.percentile(df['Poverty headcount ratio at $6.85 a day (2017 PPP) (% of population)'],98)
# Out:
# 87.64799999999995
